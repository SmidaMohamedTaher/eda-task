# %%
import pandas as pd

df = pd.read_csv("student_performance_updated_1000.csv")
df.isnull().sum()
# Out:
# StudentID                    40
# Name                         34
# Gender                       48
# AttendanceRate               40
# StudyHoursPerWeek            50
# PreviousGrade                33
# ExtracurricularActivities    43
# ParentalSupport              22
# FinalGrade                   40
# Study Hours                  24
# Attendance (%)               41
# Online Classes Taken         25
# dtype: int64

# %%
print(df.dtypes)
# Out:
# StudentID                    float64
# Name                          object
# Gender                        object
# AttendanceRate               float64
# StudyHoursPerWeek            float64
# PreviousGrade                float64
# ExtracurricularActivities    float64
# ParentalSupport               object
# FinalGrade                   float64
# Study Hours                  float64
# Attendance (%)               float64
# Online Classes Taken          object
# dtype: object

# %%
# Get all rows that have at least one null value
null_rows = df[df.isnull().any(axis=1)]

# Show the row index and which columns are null
null_info = null_rows.isnull()
print(null_info)
# Out:
#      StudentID   Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 4        False  False   False            True              False
# 5        False  False   False           False              False
# 7        False  False   False            True              False
# 10       False  False   False           False              False
# 11       False  False   False           False              False
# ..         ...    ...     ...             ...                ...
# 988      False  False   False           False              False
# 995      False  False   False           False              False
# 996      False  False   False           False               True
# 997      False   True   False           False              False
# 999      False  False   False           False              False
#
#      PreviousGrade  ExtracurricularActivities  ParentalSupport  FinalGrade  \
# 4            False                      False            False       False
# ...
